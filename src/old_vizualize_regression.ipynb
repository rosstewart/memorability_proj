# %%
import matplotlib.pyplot as plt, numpy as np

preds, labels = [],[]
with open('test_out.txt','r') as f:
    for line in f:
        id_, pred, label = line.split()
        preds.append(pred)
        labels.append(label)
preds, labels = np.array(preds).astype('float'), np.array(labels).astype('float')

# %%
# plt.scatter(preds,labels)
# plt.axis('equal')
# plt.ylim([])
Y_test = labels
Y_test_pred = preds
fig, ax = plt.subplots(1,1,constrained_layout=True)
ax.set_title('Y_test_pred vs Y_test')
ax.plot(Y_test, Y_test_pred, '.')
ymax=np.max([Y_test.max(), Y_test_pred.max()])
ax.plot(np.linspace(0,ymax, 3), np.linspace(0, ymax, 3), '-r')
ax.set_xlabel('Y_test')
ax.set_ylabel('Y_test_pred')
# Out:
# Text(0, 0.5, 'Y_test_pred')

# %%
labels[:50]
# Out:
# array([0.85714298, 0.75675702, 0.89743602, 0.902439  , 0.88      ,
#        0.55813998, 0.86842102, 0.805556  , 0.67567599, 0.73529398,
#        0.809524  , 0.76923102, 0.56410301, 0.5       , 0.84615397,
#        0.95555598, 0.92857099, 0.78048801, 0.92307699, 0.5       ,
#        0.86486501, 0.76923102, 0.64102602, 0.89999998, 0.86046499,
#        0.70967698, 0.65116298, 0.88888901, 0.71794897, 0.68571401,
#        0.92105299, 0.72973001, 0.909091  , 0.85365897, 0.91666698,
#        0.67567599, 0.78787899, 0.803922  , 0.80000001, 0.85365897,
#        0.805556  , 0.69999999, 0.60975599, 0.86111099, 0.79411799,
#        0.77777803, 0.73529398, 0.71428603, 0.30769199, 0.46808499])
